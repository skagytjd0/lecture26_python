# %% [markdown]
# ### 튜플

# %%
t1 = (1, 2, 3)
t2 = ('a', 'b', ('ab', 'cd'))
t3 = ('tuple', (1, 2), [3, 4])

print(t3)
# Out:
# ('tuple', (1, 2), [3, 4])

# %% [markdown]
# ### 튜플 만들기

# %%
t4 = ()
t5 = (1,)

t6 = 1, 2, 3
t7 = 1,

print(t6)
x, y, z = t6
print(x, y, z)
# Out:
# (1, 2, 3)
# 1 2 3
